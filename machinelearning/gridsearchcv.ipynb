# %%
# scenario1
# grid_search_cv=GridSearchCV(
#                 estimator=DecisionTreeCl̥assifier()
#                 param_grid={'max_depth':[None,10,50,100]}
#                 cv=5

                
# )
# grid_search_cv.fit(xtrain,ytrain)
# Out:
#   Cell In[1], line 3
#     estimator=DecisionTreeCl̥assifier()
#               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# scenario2
# from xgboost import train


# pipeline=pipeline(
#          steps=[
#              ('preprocessing':preprocessing),
#              ('model',DecisionTreeClassifier())
#          ]
# )
# gridsearchcv=gridsearchCV(
#     estimator:pipeline,
#     param_grid={'model__max_depth:'
#     [None,5,10,50,100]}
#     cv=5
# )
# cv=crossvalidation
# it takes 5 folds
# 13--> 3,3,3,3,1
# 10-->2,2,2,2,2
# train and test--> 5== 80 20
#                   10--> 90 10
                #   3-->66 33.33
#  5 folds-->(equally split)
# train              Test  
# cv1-f1,f2,f3,f4    f5
# cv2- f1,f3,f4,f5   f2
# cv3- f1,f2,f4,f5    f3
# cv4  f1,f2,f3,f5    f4
# cv5  f2,f3,f4,f5    f1

# 1] none,gini --> cv1- 90%
#                  cv2- 80%
#                  cv3- 75
#                  cv4-70
#                  cv5- 90
# 2]87 3]95 4] 90 5]71 6]95.7 7]95.7 8]91
# *** 8*5 ==40 times it trains
# if performance scores are same(when test is happens it gives score) it takes the first one
# cv-3 large datasets                                                                                                                 
# cv-5 moderate datsets
# cv-10 small datsets

# %%
# grid_search_cv=GridsearchCv(
#     estimator:DecisionTreeClassifier(),
#     param_grid:{'maxdepth':[None]
#                 criterion:['gini','entropy']}
#                   cv=5

# )
# njobs
# workers

# njobs-->no of jobs (-1,1,2,3,4)
# it tells jhow many cpu cores engaged to do the processes

# -1--> it uses all cpu cores 
# 5 cores-->all cpu cores 80 Fields parallelly it processes
# 1==> with 1 cpu 80 fields(80 times train)
# print(os.cpu_count()) 
# by this we can get no of cpu cores

# verbose->when n_job=1 then we can use verbose 
# helps to understand how many fields are training internally
# more verbose==> more information
# we can get info of gridsearchcv
# if u give --> verbose=0 u will not get any thing
