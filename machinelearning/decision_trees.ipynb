# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('car_evaluation.csv')

# %%
df.head()
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc
# 2  vhigh   vhigh  2   2    med   low  unacc
# 3  vhigh   vhigh  2   2    med   med  unacc
# 4  vhigh   vhigh  2   2    med  high  unacc

# %%
# exploratory data analysis
df.shape
# Out:
# (1727, 7)

# %%
# rename col names
col_names = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']
df.columns = col_names
col_names
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']

# %%
df.head()
# Out:
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    med  unacc
# 1  vhigh  vhigh     2       2    small   high  unacc
# 2  vhigh  vhigh     2       2      med    low  unacc
# 3  vhigh  vhigh     2       2      med    med  unacc
# 4  vhigh  vhigh     2       2      med   high  unacc

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1727 non-null   str
#  1   maint     1727 non-null   str
#  2   doors     1727 non-null   str
#  3   persons   1727 non-null   str
#  4   lug_boot  1727 non-null   str
#  5   safety    1727 non-null   str
#  6   class     1727 non-null   str
# dtypes: str(7)
# memory usage: 133.4 KB

# %%
# frequency ditribution
col_names = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']


for col in col_names:
    
    print(df[col].value_counts())
# Out:
# buying
# high     432
# med      432
# low      432
# vhigh    431
# Name: count, dtype: int64
# maint
# high     432
# med      432
# low      432
# vhigh    431
# Name: count, dtype: int64
# doors
# 3        432
# 4        432
# 5more    432
# 2        431
# Name: count, dtype: int64
# persons
# 4       576
# more    576
# 2       575
# Name: count, dtype: int64
# lug_boot
# med      576
# big      576
# small    575
# Name: count, dtype: int64
# safety
# med     576
# high    576
# low     575
# Name: count, dtype: int64
# class
# unacc    1209
# acc       384
# good       69
# vgood      65
# Name: count, dtype: int64

# %%
# conclusion
# There are 7 variables in the dataset. All the variables are of categorical data type.
# These are given by buying, maint, doors, persons, lug_boot, safety and class.
# class is the target variable.

# %%
# exploring class variable
df['class'].value_counts()
# Out:
# class
# unacc    1209
# acc       384
# good       69
# vgood      65
# Name: count, dtype: int64

# %%
# Missing values in variables¶
df.isnull().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# class       0
# dtype: int64

# %%
# declare x and y
X = df.drop('class', axis=1)
y = df['class']

# %%
# split data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
X_train.shape, X_test.shape
# Out:
# ((1157, 6), (570, 6))

# %%
# Feature Engineering
X_train.astype('object').dtypes
# Out:
# buying      object
# maint       object
# doors       object
# persons     object
# lug_boot    object
# safety      object
# dtype: object

# %%
X_train.head()
# Out:
#      buying  maint  doors persons lug_boot safety
# 83    vhigh  vhigh  5more       2      med    low
# 48    vhigh  vhigh      3    more      med    med
# 468    high  vhigh      3       4    small    med
# 155   vhigh   high      3    more      med    low
# 1043    med   high      4    more    small    low

# %%
pip install category_encoders
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting category_encoders
#   Downloading category_encoders-2.9.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.14.0 in C:\Users\Dell\AppData\Roaming\Python\Python314\site-packages (from category_encoders) (2.4.4)
# Requirement already satisfied: pandas>=1.0.5 in C:\Users\Dell\AppData\Roaming\Python\Python314\site-packages (from category_encoders) (3.0.2)
# Collecting patsy>=0.5.1 (from category_encoders)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: scikit-learn>=1.6.0 in C:\Users\Dell\AppData\Roaming\Python\Python314\site-packages (from category_encoders) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in C:\Users\Dell\AppData\Roaming\Python\Python314\site-packages (from category_encoders) (1.17.1)
# Collecting statsmodels>=0.9.0 (from category_encoders)
#   Downloading statsmodels-0.14.6-cp314-cp314-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Dell\AppData\Roaming\Python\Python314\site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Dell\AppData\Roaming\Python\Python314\site-packages (from pandas>=1.0.5->category_encoders) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\Dell\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\Dell\AppData\Roaming\Python\Python314\site-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\Dell\AppData\Roaming\Python\Python314\site-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in C:\Users\Dell\AppData\Roaming\Python\Python314\site-packages (from statsmodels>=0.9.0->category_encoders) (26.0)
# Downloading category_encoders-2.9.0-py3-none-any.whl (85 kB)
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Downloading statsmodels-0.14.6-cp314-cp314-win_amd64.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.6 MB 829.7 kB/s eta 0:00:11
#    -- ------------------------------------- 0.5/9.6 MB 829.7 kB/s eta 0:00:11
#    --- ------------------------------------ 0.8/9.6 MB 839.0 kB/s eta 0:00:11
#    --- ------------------------------------ 0.8/9.6 MB 839.0 kB/s eta 0:00:11
#    ---- ----------------------------------- 1.0/9.6 MB 693.0 kB/s eta 0:00:13
#    ----- ---------------------------------- 1.3/9.6 MB 725.3 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.3/9.6 MB 725.3 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.3/9.6 MB 725.3 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.3/9.6 MB 725.3 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.3/9.6 MB 725.3 kB/s eta 0:00:12
#    ------ --------------------------------- 1.6/9.6 MB 529.0 kB/s eta 0:00:16
#    ------ --------------------------------- 1.6/9.6 MB 529.0 kB/s eta 0:00:16
#    ------ --------------------------------- 1.6/9.6 MB 529.0 kB/s eta 0:00:16
#    ------ --------------------------------- 1.6/9.6 MB 529.0 kB/s eta 0:00:16
#    ------ --------------------------------- 1.6/9.6 MB 529.0 kB/s eta 0:00:16
#    ------- -------------------------------- 1.8/9.6 MB 445.8 kB/s eta 0:00:18
#    ------- -------------------------------- 1.8/9.6 MB 445.8 kB/s eta 0:00:18
#    ------- -------------------------------- 1.8/9.6 MB 445.8 kB/s eta 0:00:18
#    -------- ------------------------------- 2.1/9.6 MB 431.8 kB/s eta 0:00:18
#    -------- ------------------------------- 2.1/9.6 MB 431.8 kB/s eta 0:00:18
#    -------- ------------------------------- 2.1/9.6 MB 431.8 kB/s eta 0:00:18
#    --------- ------------------------------ 2.4/9.6 MB 444.8 kB/s eta 0:00:17
#    ---------- ----------------------------- 2.6/9.6 MB 473.2 kB/s eta 0:00:15
#    ------------ --------------------------- 2.9/9.6 MB 501.6 kB/s eta 0:00:14
#    ------------- -------------------------- 3.1/9.6 MB 525.5 kB/s eta 0:00:13
#    ------------- -------------------------- 3.1/9.6 MB 525.5 kB/s eta 0:00:13
#    -------------- ------------------------- 3.4/9.6 MB 543.8 kB/s eta 0:00:12
#    --------------- ------------------------ 3.7/9.6 MB 559.2 kB/s eta 0:00:11
#    ---------------- ----------------------- 3.9/9.6 MB 578.3 kB/s eta 0:00:10
#    ----------------- ---------------------- 4.2/9.6 MB 604.1 kB/s eta 0:00:09
#    ------------------ --------------------- 4.5/9.6 MB 625.4 kB/s eta 0:00:09
#    ------------------- -------------------- 4.7/9.6 MB 644.5 kB/s eta 0:00:08
#    -------------------- ------------------- 5.0/9.6 MB 657.7 kB/s eta 0:00:08
#    --------------------- ------------------ 5.2/9.6 MB 665.8 kB/s eta 0:00:07
#    ---------------------- ----------------- 5.5/9.6 MB 682.9 kB/s eta 0:00:06
#    ------------------------ --------------- 5.8/9.6 MB 702.6 kB/s eta 0:00:06
#    ------------------------- -------------- 6.0/9.6 MB 721.5 kB/s eta 0:00:05
#    --------------------------- ------------ 6.6/9.6 MB 753.4 kB/s eta 0:00:05
#    ---------------------------- ----------- 6.8/9.6 MB 770.4 kB/s eta 0:00:04
#    ----------------------------- ---------- 7.1/9.6 MB 788.1 kB/s eta 0:00:04
#    ------------------------------ --------- 7.3/9.6 MB 802.8 kB/s eta 0:00:03
#    -------------------------------- ------- 7.9/9.6 MB 829.7 kB/s eta 0:00:03
#    --------------------------------- ------ 8.1/9.6 MB 838.3 kB/s eta 0:00:02
#    ---------------------------------- ----- 8.4/9.6 MB 847.8 kB/s eta 0:00:02
#    ------------------------------------ --- 8.7/9.6 MB 853.4 kB/s eta 0:00:02
#    ------------------------------------- -- 8.9/9.6 MB 862.2 kB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.6 MB 870.1 kB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 882.6 kB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 879.3 kB/s  0:00:11
# Installing collected packages: patsy, statsmodels, category_encoders
#
#    ---------------------------------------- 0/3 [patsy]
#    ---------------------------------------- 0/3 [patsy]
#    ---------------------------------------- 0/3 [patsy]
#    ---------------------------------------- 0/3 [patsy]
#    ---------------------------------------- 0/3 [patsy]
#    ---------------------------------------- 0/3 [patsy]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    -------------------------- ------------- 2/3 [category_encoders]
#    -------------------------- ------------- 2/3 [category_encoders]
#    -------------------------- ------------- 2/3 [category_encoders]
#    -------------------------- ------------- 2/3 [category_encoders]
#    ---------------------------------------- 3/3 [category_encoders]
#
# Successfully installed category_encoders-2.9.0 patsy-1.0.2 statsmodels-0.14.6
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import category_encoders as ce

# %%
encoder = ce.OrdinalEncoder(cols=['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety'])

# %%
X_train = encoder.fit_transform(X_train)

X_test = encoder.transform(X_test)

# %%
X_train.head()
# Out:
#       buying  maint  doors  persons  lug_boot  safety
# 83         1      1      1        1         1       1
# 48         1      1      2        2         1       2
# 468        2      1      2        3         2       2
# 155        1      2      2        2         1       1
# 1043       3      2      3        2         2       1

# %%
X_test.head()
# Out:
#       buying  maint  doors  persons  lug_boot  safety
# 599        2      2      3        1         3       1
# 932        3      1      3        3         3       1
# 628        2      2      1        1         3       3
# 1497       4      2      1        3         1       2
# 1262       3      4      3        2         1       1

# %%
# Decision Tree Classifier with criterion gini index
from sklearn.tree import DecisionTreeClassifier

# %%
clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=0)
clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
y_pred_gini = clf_gini.predict(X_test)

# %%
# accuracy
from sklearn.metrics import accuracy_score

print('Model accuracy score with criterion gini index: {0:0.4f}'. format(accuracy_score(y_test, y_pred_gini)))
# Out:
# Model accuracy score with criterion gini index: 0.8053

# %%
# train accuracy
y_pred_train_gini = clf_gini.predict(X_train)

y_pred_train_gini
# Out:
# array(['unacc', 'unacc', 'unacc', ..., 'unacc', 'unacc', 'acc'],
#       shape=(1157,), dtype=object)

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train_gini)))
# Out:
# Training-set accuracy score: 0.7848

# %%
# check for overfitting
print('Training set score: {:.4f}'.format(clf_gini.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(clf_gini.score(X_test, y_test)))
# Out:
# Training set score: 0.7848
# Test set score: 0.8053

# %%
# visualize gini
plt.figure(figsize=(12,8))

from sklearn import tree

tree.plot_tree(clf_gini.fit(X_train, y_train))
# Out:
# [Text(0.3333333333333333, 0.875, 'x[5] <= 1.5\ngini = 0.457\nsamples = 1157\nvalue = [257, 51, 810, 39]'),
#  Text(0.16666666666666666, 0.625, 'gini = 0.0\nsamples = 391\nvalue = [0, 0, 391, 0]'),
#  Text(0.25, 0.75, 'True  '),
#  Text(0.5, 0.625, 'x[3] <= 1.5\ngini = 0.581\nsamples = 766\nvalue = [257, 51, 419, 39]'),
#  Text(0.41666666666666663, 0.75, '  False'),
#  Text(0.3333333333333333, 0.375, 'gini = 0.0\nsamples = 242\nvalue = [0, 0, 242, 0]'),
#  Text(0.6666666666666666, 0.375, 'x[0] <= 2.5\ngini = 0.63\nsamples = 524\nvalue = [257, 51, 177, 39]'),
#  Text(0.5, 0.125, 'gini = 0.498\nsamples = 266\nvalue = [124, 0, 142, 0]'),
#  Text(0.8333333333333334, 0.125, 'gini = 0.654\nsamples = 258\nvalue = [133, 51, 35, 39]')]

# %%
#  Decision Tree Classifier with criterion entropy
clf_en = DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)
clf_en.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)

# %%
y_pred_en = clf_en.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score with criterion entropy: {0:0.4f}'. format(accuracy_score(y_test, y_pred_en)))
# Out:
# Model accuracy score with criterion entropy: 0.8053

# %%
# train accuracy
y_pred_train_en = clf_en.predict(X_train)

y_pred_train_en
# Out:
# array(['unacc', 'unacc', 'unacc', ..., 'unacc', 'unacc', 'acc'],
#       shape=(1157,), dtype=object)

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train_en)))
# Out:
# Training-set accuracy score: 0.7848

# %%
print('Training set score: {:.4f}'.format(clf_en.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(clf_en.score(X_test, y_test)))
# Out:
# Training set score: 0.7848
# Test set score: 0.8053

# %%
# visualization of Decision Tree
plt.figure(figsize=(12,8))

from sklearn import tree

tree.plot_tree(clf_en.fit(X_train, y_train))
# Out:
# [Text(0.3333333333333333, 0.875, 'x[5] <= 1.5\nentropy = 1.206\nsamples = 1157\nvalue = [257, 51, 810, 39]'),
#  Text(0.16666666666666666, 0.625, 'entropy = 0.0\nsamples = 391\nvalue = [0, 0, 391, 0]'),
#  Text(0.25, 0.75, 'True  '),
#  Text(0.5, 0.625, 'x[3] <= 1.5\nentropy = 1.484\nsamples = 766\nvalue = [257, 51, 419, 39]'),
#  Text(0.41666666666666663, 0.75, '  False'),
#  Text(0.3333333333333333, 0.375, 'entropy = 0.0\nsamples = 242\nvalue = [0, 0, 242, 0]'),
#  Text(0.6666666666666666, 0.375, 'x[0] <= 2.5\nentropy = 1.639\nsamples = 524\nvalue = [257, 51, 177, 39]'),
#  Text(0.5, 0.125, 'entropy = 0.997\nsamples = 266\nvalue = [124, 0, 142, 0]'),
#  Text(0.8333333333333334, 0.125, 'entropy = 1.758\nsamples = 258\nvalue = [133, 51, 35, 39]')]

# %%
# CONFUSION MATRIX
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_en)

print('Confusion matrix\n\n', cm)
# Out:
# Confusion matrix
#
#  [[ 71   0  56   0]
#  [ 18   0   0   0]
#  [ 11   0 388   0]
#  [ 26   0   0   0]]

# %%
# CLASSIFICATION REPORT
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_en))
# Out:
#               precision    recall  f1-score   support
#
#          acc       0.56      0.56      0.56       127
#         good       0.00      0.00      0.00        18
#        unacc       0.87      0.97      0.92       399
#        vgood       0.00      0.00      0.00        26
#
#     accuracy                           0.81       570
#    macro avg       0.36      0.38      0.37       570
# weighted avg       0.74      0.81      0.77       570
# C:\Users\Dell\AppData\Roaming\Python\Python314\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Dell\AppData\Roaming\Python\Python314\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Dell\AppData\Roaming\Python\Python314\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
In this project, I build a Decision-Tree Classifier model to predict the safety of the car. I build two models, one with criterion gini index and another one with criterion entropy. The model yields a very good performance as indicated by the model accuracy in both the cases which was found to be 0.8021.
In the model with criterion gini index, the training-set accuracy score is 0.7848 while the test-set accuracy to be 0.8053. These two values are quite comparable. So, there is no sign of overfitting.
Similarly, in the model with criterion entropy, the training-set accuracy score is 0.7848 while the test-set accuracy to be 0.8053.We get the same values as in the case with criterion gini. So, there is no sign of overfitting.
In both the cases, the training-set and test-set accuracy score is the same. It may happen because of small dataset.
